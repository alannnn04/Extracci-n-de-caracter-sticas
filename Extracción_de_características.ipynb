# %% [markdown]
# <a href="https://colab.research.google.com/github/alannnn04/Extracci-n-de-caracter-sticas/blob/main/Extracci%C3%B3n_de_caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head(2)
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
#
#            228_store_name 229_store_picture               232_type_of_store  \
# 0     Eugene’s Compostura           1 Photo                          Tailor
# 1  Frutas y verduras Angy           1 Photo  Grocery store (aka. nanostore)
#
#    ... 261_technology_organization 262_technology_serve_customers  \
# 0  ...                         NaN                            NaN
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer)
# Out:
#                                _record_id  frequency  percentage  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b          1    0.005848
# 1    53c25f08-1c1b-4c1c-97d5-b45c940735cc          1    0.005848
# 2    af5c48b5-a916-47a6-aacc-1128ea1e728e          1    0.005848
# 3    4790411b-df1d-44f0-a659-6d99e26ae765          1    0.005848
# 4    e70db20a-25db-412b-9a71-7df285c92a3d          1    0.005848
# ..                                    ...        ...         ...
# 166  75bcc709-90ff-4db7-bb82-293f2f72f3ae          1    0.005848
# 167  bd59c8b6-81cb-4698-8cfd-dbab7f01ef21          1    0.005848
# 168  94b1c6bc-1fb8-4895-aacc-c2604dc12b93          1    0.005848
# 169  d9ff4194-657e-4fb4-b5f4-b7e8b350a646          1    0.005848
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c          1    0.005848
#
#      cumulative_perc
# 0           0.005848
# 1           0.011696
# 2           0.017544
# 3           0.023392
# 4           0.029240
# ..               ...
# 166         0.976608
# ...

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , 4:7]
Filtro=Micro_Retailer.loc[ : , ["58_willingness_share_sales_data_mse", "43_willingness_share_sales_data_suppliers", "47_willingness_reorder_suppliers_lower_prices", "46_willingness_reorder_suppliers_variety", "45_willingness_reorder_suppliers", "44_willingness_inventory_management_suppliers", "42_willingness_share_inventory_data_suppliers", "314_reception_delivery_packages", "313_home_deliveries" , "312_payment_of_utilities", "311_topups", "69_why_not_services", "60_services", "_title", "193_sales_planning_tools"  , "214_customer_relationship_tools", "189_payment_methods" , "210_sales_channels"  ,  "18_sales_records"  ,
  "5_change_store_space_last_year" ]]  #columnas no consecutivas
Filtro
# Out:
#     58_willingness_share_sales_data_mse  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 166                                 NaN
# 167                                 NaN
# 168                                 NaN
# 169                                 NaN
# 170                                 NaN
#
#     43_willingness_share_sales_data_suppliers  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 166                                       NaN
# 167                                       NaN
# 168                                       NaN
# ...

# %%
#Verificamos información del DataFrame
Filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 20 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   58_willingness_share_sales_data_mse            68 non-null     object
#  1   43_willingness_share_sales_data_suppliers      70 non-null     object
#  2   47_willingness_reorder_suppliers_lower_prices  69 non-null     object
#  3   46_willingness_reorder_suppliers_variety       74 non-null     object
#  4   45_willingness_reorder_suppliers               77 non-null     object
#  5   44_willingness_inventory_management_suppliers  79 non-null     object
#  6   42_willingness_share_inventory_data_suppliers  80 non-null     object
#  7   314_reception_delivery_packages                68 non-null     object
#  8   313_home_deliveries                            58 non-null     object
# ...

# %% [markdown]
# **Sustitución de Valores Nulos**

# %%
#Identificar valores nulos por columna
valores_nulos=Filtro.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse              103
# 43_willingness_share_sales_data_suppliers        101
# 47_willingness_reorder_suppliers_lower_prices    102
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Realizamos una copia del dataframe
Filtro1=Filtro.copy()

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["58_willingness_share_sales_data_mse"] =Filtro1["58_willingness_share_sales_data_mse"].fillna(method="ffill")
# Out:
# <ipython-input-16-4443e9211800>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["58_willingness_share_sales_data_mse"] =Filtro1["58_willingness_share_sales_data_mse"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               10
# 43_willingness_share_sales_data_suppliers        101
# 47_willingness_reorder_suppliers_lower_prices    102
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["58_willingness_share_sales_data_mse"] =Filtro1["58_willingness_share_sales_data_mse"].fillna(method="bfill")
# Out:
# <ipython-input-18-2cf33431c3db>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["58_willingness_share_sales_data_mse"] =Filtro1["58_willingness_share_sales_data_mse"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers        101
# 47_willingness_reorder_suppliers_lower_prices    102
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["43_willingness_share_sales_data_suppliers"] =Filtro1["43_willingness_share_sales_data_suppliers"].fillna(method="bfill")
# Out:
# <ipython-input-20-d8a53bfa95c9>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["43_willingness_share_sales_data_suppliers"] =Filtro1["43_willingness_share_sales_data_suppliers"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          5
# 47_willingness_reorder_suppliers_lower_prices    102
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["43_willingness_share_sales_data_suppliers"] =Filtro1["43_willingness_share_sales_data_suppliers"].fillna(method="ffill")
# Out:
# <ipython-input-22-0f677fdae260>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["43_willingness_share_sales_data_suppliers"] =Filtro1["43_willingness_share_sales_data_suppliers"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices    102
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["47_willingness_reorder_suppliers_lower_prices"] =Filtro1["47_willingness_reorder_suppliers_lower_prices"].fillna(method="ffill")
# Out:
# <ipython-input-24-58e66dc0e4e5>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["47_willingness_reorder_suppliers_lower_prices"] =Filtro1["47_willingness_reorder_suppliers_lower_prices"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices     10
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["47_willingness_reorder_suppliers_lower_prices"] =Filtro1["47_willingness_reorder_suppliers_lower_prices"].fillna(method="bfill")
# Out:
# <ipython-input-26-49a8b3b98721>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["47_willingness_reorder_suppliers_lower_prices"] =Filtro1["47_willingness_reorder_suppliers_lower_prices"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety          97
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["46_willingness_reorder_suppliers_variety"] =Filtro1["46_willingness_reorder_suppliers_variety"].fillna(method="ffill")
# Out:
# <ipython-input-28-0b9fd42fc256>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["46_willingness_reorder_suppliers_variety"] =Filtro1["46_willingness_reorder_suppliers_variety"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           6
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["46_willingness_reorder_suppliers_variety"] =Filtro1["46_willingness_reorder_suppliers_variety"].fillna(method="bfill")
# Out:
# <ipython-input-30-40bfc9b3d1ad>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["46_willingness_reorder_suppliers_variety"] =Filtro1["46_willingness_reorder_suppliers_variety"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                  94
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["45_willingness_reorder_suppliers"] =Filtro1["45_willingness_reorder_suppliers"].fillna(method="ffill")
# Out:
# <ipython-input-33-8b6fe24bf182>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["45_willingness_reorder_suppliers"] =Filtro1["45_willingness_reorder_suppliers"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   6
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["45_willingness_reorder_suppliers"] =Filtro1["45_willingness_reorder_suppliers"].fillna(method="bfill")
# Out:
# <ipython-input-35-09a5d69f30a5>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["45_willingness_reorder_suppliers"] =Filtro1["45_willingness_reorder_suppliers"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers     92
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["44_willingness_inventory_management_suppliers"] =Filtro1["44_willingness_inventory_management_suppliers"].fillna(method="ffill")
# Out:
# <ipython-input-37-d6a8307baac0>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["44_willingness_inventory_management_suppliers"] =Filtro1["44_willingness_inventory_management_suppliers"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      6
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["44_willingness_inventory_management_suppliers"] =Filtro1["44_willingness_inventory_management_suppliers"].fillna(method="bfill")
# Out:
# <ipython-input-39-2277b312a946>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["44_willingness_inventory_management_suppliers"] =Filtro1["44_willingness_inventory_management_suppliers"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers     91
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["42_willingness_share_inventory_data_suppliers"] =Filtro1["42_willingness_share_inventory_data_suppliers"].fillna(method="ffill")
# Out:
# <ipython-input-41-cb14acd764c4>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["42_willingness_share_inventory_data_suppliers"] =Filtro1["42_willingness_share_inventory_data_suppliers"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      6
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["42_willingness_share_inventory_data_suppliers"] =Filtro1["42_willingness_share_inventory_data_suppliers"].fillna(method="bfill")
# Out:
# <ipython-input-43-356a4ca43e7c>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["42_willingness_share_inventory_data_suppliers"] =Filtro1["42_willingness_share_inventory_data_suppliers"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                  103
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["314_reception_delivery_packages"] =Filtro1["314_reception_delivery_packages"].fillna(method="ffill")
# Out:
# <ipython-input-45-38043ea2d72f>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["314_reception_delivery_packages"] =Filtro1["314_reception_delivery_packages"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                   10
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["314_reception_delivery_packages"] =Filtro1["314_reception_delivery_packages"].fillna(method="bfill")
# Out:
# <ipython-input-47-2e7771744141>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["314_reception_delivery_packages"] =Filtro1["314_reception_delivery_packages"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                              113
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["313_home_deliveries"] =Filtro1["313_home_deliveries"].fillna(method="ffill")
# Out:
# <ipython-input-49-4a9b5e75f26f>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["313_home_deliveries"] =Filtro1["313_home_deliveries"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                               10
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["313_home_deliveries"] =Filtro1["313_home_deliveries"].fillna(method="bfill")
# Out:
# <ipython-input-51-6803a8092a29>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["313_home_deliveries"] =Filtro1["313_home_deliveries"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                                0
# 312_payment_of_utilities                         105
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["312_payment_of_utilities"] =Filtro1["312_payment_of_utilities"].fillna(method="ffill")
# Out:
# <ipython-input-53-7f7c2d350bc8>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["312_payment_of_utilities"] =Filtro1["312_payment_of_utilities"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                                0
# 312_payment_of_utilities                          10
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["312_payment_of_utilities"] =Filtro1["312_payment_of_utilities"].fillna(method="bfill")
# Out:
# <ipython-input-55-77e50aa0df8e>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["312_payment_of_utilities"] =Filtro1["312_payment_of_utilities"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                                0
# 312_payment_of_utilities                           0
# 311_topups                                       114
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["311_topups"] =Filtro1["311_topups"].fillna(method="ffill")
# Out:
# <ipython-input-57-e520b7fa8f9e>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["311_topups"] =Filtro1["311_topups"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                                0
# 312_payment_of_utilities                           0
# 311_topups                                        10
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["311_topups"] =Filtro1["311_topups"].fillna(method="bfill")
# Out:
# <ipython-input-59-5809e5a6ae77>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["311_topups"] =Filtro1["311_topups"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse                0
# 43_willingness_share_sales_data_suppliers          0
# 47_willingness_reorder_suppliers_lower_prices      0
# 46_willingness_reorder_suppliers_variety           0
# 45_willingness_reorder_suppliers                   0
# 44_willingness_inventory_management_suppliers      0
# 42_willingness_share_inventory_data_suppliers      0
# 314_reception_delivery_packages                    0
# 313_home_deliveries                                0
# 312_payment_of_utilities                           0
# 311_topups                                         0
# 69_why_not_services                              130
# 60_services                                       94
# _title                                             0
# 193_sales_planning_tools                          89
# 214_customer_relationship_tools                   76
# 189_payment_methods                               64
# 210_sales_channels                                89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["69_why_not_services"] =Filtro1["69_why_not_services"].fillna(method="ffill")
# Out:
# <ipython-input-61-6a025b0e74dd>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["69_why_not_services"] =Filtro1["69_why_not_services"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                              10
# 60_services                                      94
# _title                                            0
# 193_sales_planning_tools                         89
# 214_customer_relationship_tools                  76
# 189_payment_methods                              64
# 210_sales_channels                               89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["69_why_not_services"] =Filtro1["69_why_not_services"].fillna(method="bfill")
# Out:
# <ipython-input-63-20a33b61c681>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["69_why_not_services"] =Filtro1["69_why_not_services"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                      94
# _title                                            0
# 193_sales_planning_tools                         89
# 214_customer_relationship_tools                  76
# 189_payment_methods                              64
# 210_sales_channels                               89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["60_services"] =Filtro1["60_services"].fillna(method="ffill")
# Out:
# <ipython-input-65-f8d6bcc57eee>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["60_services"] =Filtro1["60_services"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                      10
# _title                                            0
# 193_sales_planning_tools                         89
# 214_customer_relationship_tools                  76
# 189_payment_methods                              64
# 210_sales_channels                               89
# ...

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Filtro1["60_services"] =Filtro1["60_services"].fillna(method="bfill")
# Out:
# <ipython-input-67-4d5d9cacfc95>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["60_services"] =Filtro1["60_services"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                       0
# _title                                            0
# 193_sales_planning_tools                         89
# 214_customer_relationship_tools                  76
# 189_payment_methods                              64
# 210_sales_channels                               89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["193_sales_planning_tools"] =Filtro1["193_sales_planning_tools"].fillna(method="ffill")
# Out:
# <ipython-input-69-dd7690ef0237>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["193_sales_planning_tools"] =Filtro1["193_sales_planning_tools"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                       0
# _title                                            0
# 193_sales_planning_tools                          0
# 214_customer_relationship_tools                  76
# 189_payment_methods                              64
# 210_sales_channels                               89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["214_customer_relationship_tools"] =Filtro1["214_customer_relationship_tools"].fillna(method="ffill")
# Out:
# <ipython-input-71-e510d86d8441>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["214_customer_relationship_tools"] =Filtro1["214_customer_relationship_tools"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                       0
# _title                                            0
# 193_sales_planning_tools                          0
# 214_customer_relationship_tools                   0
# 189_payment_methods                              64
# 210_sales_channels                               89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["189_payment_methods"] =Filtro1["189_payment_methods"].fillna(method="ffill")
# Out:
# <ipython-input-73-0f4b78423d7d>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["189_payment_methods"] =Filtro1["189_payment_methods"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                       0
# _title                                            0
# 193_sales_planning_tools                          0
# 214_customer_relationship_tools                   0
# 189_payment_methods                               0
# 210_sales_channels                               89
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["210_sales_channels"] =Filtro1["210_sales_channels"].fillna(method="ffill")
# Out:
# <ipython-input-75-35e3f6ad50c1>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["210_sales_channels"] =Filtro1["210_sales_channels"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                       0
# _title                                            0
# 193_sales_planning_tools                          0
# 214_customer_relationship_tools                   0
# 189_payment_methods                               0
# 210_sales_channels                                0
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["18_sales_records"] =Filtro1["18_sales_records"].fillna(method="ffill")
# Out:
# <ipython-input-77-e8068a0da9df>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["18_sales_records"] =Filtro1["18_sales_records"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse               0
# 43_willingness_share_sales_data_suppliers         0
# 47_willingness_reorder_suppliers_lower_prices     0
# 46_willingness_reorder_suppliers_variety          0
# 45_willingness_reorder_suppliers                  0
# 44_willingness_inventory_management_suppliers     0
# 42_willingness_share_inventory_data_suppliers     0
# 314_reception_delivery_packages                   0
# 313_home_deliveries                               0
# 312_payment_of_utilities                          0
# 311_topups                                        0
# 69_why_not_services                               0
# 60_services                                       0
# _title                                            0
# 193_sales_planning_tools                          0
# 214_customer_relationship_tools                   0
# 189_payment_methods                               0
# 210_sales_channels                                0
# ...

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Filtro1["5_change_store_space_last_year"] =Filtro1["5_change_store_space_last_year"].fillna(method="ffill")
# Out:
# <ipython-input-79-c93968e0ff1e>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Filtro1["5_change_store_space_last_year"] =Filtro1["5_change_store_space_last_year"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Filtro1.isnull().sum()
valores_nulos
# Out:
# 58_willingness_share_sales_data_mse              0
# 43_willingness_share_sales_data_suppliers        0
# 47_willingness_reorder_suppliers_lower_prices    0
# 46_willingness_reorder_suppliers_variety         0
# 45_willingness_reorder_suppliers                 0
# 44_willingness_inventory_management_suppliers    0
# 42_willingness_share_inventory_data_suppliers    0
# 314_reception_delivery_packages                  0
# 313_home_deliveries                              0
# 312_payment_of_utilities                         0
# 311_topups                                       0
# 69_why_not_services                              0
# 60_services                                      0
# _title                                           0
# 193_sales_planning_tools                         0
# 214_customer_relationship_tools                  0
# 189_payment_methods                              0
# 210_sales_channels                               0
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Filtro1)
# Out:
#   58_willingness_share_sales_data_mse  frequency  percentage  cumulative_perc
# 0            Totalmente en desacuerdo        115    0.672515         0.672515
# 1               Totalmente de acuerdo         19    0.111111         0.783626
# 2                  Algo en desacuerdo         14    0.081871         0.865497
# 3                     Algo de acuerdo         13    0.076023         0.941520
# 4      Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000
#
# ----------------------------------------------------------------
#
#   43_willingness_share_sales_data_suppliers  frequency  percentage  \
# 0                  Totalmente en desacuerdo        112    0.654971
# 1                        Algo en desacuerdo         26    0.152047
# 2                           Algo de acuerdo         16    0.093567
# 3                     Totalmente de acuerdo          9    0.052632
# 4            Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# ...

# %% [markdown]
# **Análisis univariado**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Filtro1['58_willingness_share_sales_data_mse'])
table1
# Out:
#   58_willingness_share_sales_data_mse  frequency  percentage  cumulative_perc
# 0            Totalmente en desacuerdo        115    0.672515         0.672515
# 1               Totalmente de acuerdo         19    0.111111         0.783626
# 2                  Algo en desacuerdo         14    0.081871         0.865497
# 3                     Algo de acuerdo         13    0.076023         0.941520
# 4      Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro01= table1[table1['frequency']>1]
Filtro01
# Out:
#   58_willingness_share_sales_data_mse  frequency  percentage  cumulative_perc
# 0            Totalmente en desacuerdo        115    0.672515         0.672515
# 1               Totalmente de acuerdo         19    0.111111         0.783626
# 2                  Algo en desacuerdo         14    0.081871         0.865497
# 3                     Algo de acuerdo         13    0.076023         0.941520
# 4      Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro01.set_index('58_willingness_share_sales_data_mse')
Filtro_index
# Out:
#                                      frequency  percentage  cumulative_perc
# 58_willingness_share_sales_data_mse
# Totalmente en desacuerdo                   115    0.672515         0.672515
# Totalmente de acuerdo                       19    0.111111         0.783626
# Algo en desacuerdo                          14    0.081871         0.865497
# Algo de acuerdo                             13    0.076023         0.941520
# Ni de acuerdo ni en desacuerdo              10    0.058480         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('58_willingness_share_sales_data_mse')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(Filtro1['43_willingness_share_sales_data_suppliers'])
table2
# Out:
#   43_willingness_share_sales_data_suppliers  frequency  percentage  \
# 0                  Totalmente en desacuerdo        112    0.654971
# 1                        Algo en desacuerdo         26    0.152047
# 2                           Algo de acuerdo         16    0.093567
# 3                     Totalmente de acuerdo          9    0.052632
# 4            Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.654971
# 1         0.807018
# 2         0.900585
# 3         0.953216
# 4         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table2[table2['frequency']>1]
Filtro2
# Out:
#   43_willingness_share_sales_data_suppliers  frequency  percentage  \
# 0                  Totalmente en desacuerdo        112    0.654971
# 1                        Algo en desacuerdo         26    0.152047
# 2                           Algo de acuerdo         16    0.093567
# 3                     Totalmente de acuerdo          9    0.052632
# 4            Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.654971
# 1         0.807018
# 2         0.900585
# 3         0.953216
# 4         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index2= Filtro2.set_index('43_willingness_share_sales_data_suppliers')
Filtro_index2
# Out:
#                                            frequency  percentage  \
# 43_willingness_share_sales_data_suppliers
# Totalmente en desacuerdo                         112    0.654971
# Algo en desacuerdo                                26    0.152047
# Algo de acuerdo                                   16    0.093567
# Totalmente de acuerdo                              9    0.052632
# Ni de acuerdo ni en desacuerdo                     8    0.046784
#
#                                            cumulative_perc
# 43_willingness_share_sales_data_suppliers
# Totalmente en desacuerdo                          0.654971
# Algo en desacuerdo                                0.807018
# Algo de acuerdo                                   0.900585
# Totalmente de acuerdo                             0.953216
# Ni de acuerdo ni en desacuerdo                    1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index2.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='43_willingness_share_sales_data_suppliers'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(Filtro1['47_willingness_reorder_suppliers_lower_prices'])
table3
# Out:
#   47_willingness_reorder_suppliers_lower_prices  frequency  percentage  \
# 0                      Totalmente en desacuerdo         97    0.567251
# 1                               Algo de acuerdo         33    0.192982
# 2                         Totalmente de acuerdo         18    0.105263
# 3                            Algo en desacuerdo         15    0.087719
# 4                Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.567251
# 1         0.760234
# 2         0.865497
# 3         0.953216
# 4         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro3= table3[table3['frequency']>1]
Filtro3
# Out:
#   47_willingness_reorder_suppliers_lower_prices  frequency  percentage  \
# 0                      Totalmente en desacuerdo         97    0.567251
# 1                               Algo de acuerdo         33    0.192982
# 2                         Totalmente de acuerdo         18    0.105263
# 3                            Algo en desacuerdo         15    0.087719
# 4                Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.567251
# 1         0.760234
# 2         0.865497
# 3         0.953216
# 4         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index3= Filtro3.set_index('47_willingness_reorder_suppliers_lower_prices')
Filtro_index3
# Out:
#                                                frequency  percentage  \
# 47_willingness_reorder_suppliers_lower_prices
# Totalmente en desacuerdo                              97    0.567251
# Algo de acuerdo                                       33    0.192982
# Totalmente de acuerdo                                 18    0.105263
# Algo en desacuerdo                                    15    0.087719
# Ni de acuerdo ni en desacuerdo                         8    0.046784
#
#                                                cumulative_perc
# 47_willingness_reorder_suppliers_lower_prices
# Totalmente en desacuerdo                              0.567251
# Algo de acuerdo                                       0.760234
# Totalmente de acuerdo                                 0.865497
# Algo en desacuerdo                                    0.953216
# Ni de acuerdo ni en desacuerdo                        1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index3["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(Filtro1['46_willingness_reorder_suppliers_variety'])
table4
# Out:
#   46_willingness_reorder_suppliers_variety  frequency  percentage  \
# 0                 Totalmente en desacuerdo         73    0.426901
# 1                          Algo de acuerdo         42    0.245614
# 2                    Totalmente de acuerdo         27    0.157895
# 3                       Algo en desacuerdo         19    0.111111
# 4           Ni de acuerdo ni en desacuerdo         10    0.058480
#
#    cumulative_perc
# 0         0.426901
# 1         0.672515
# 2         0.830409
# 3         0.941520
# 4         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro4= table4[table4['frequency']>1]
Filtro4
# Out:
#   46_willingness_reorder_suppliers_variety  frequency  percentage  \
# 0                 Totalmente en desacuerdo         73    0.426901
# 1                          Algo de acuerdo         42    0.245614
# 2                    Totalmente de acuerdo         27    0.157895
# 3                       Algo en desacuerdo         19    0.111111
# 4           Ni de acuerdo ni en desacuerdo         10    0.058480
#
#    cumulative_perc
# 0         0.426901
# 1         0.672515
# 2         0.830409
# 3         0.941520
# 4         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index4= Filtro4.set_index('46_willingness_reorder_suppliers_variety')
Filtro_index4
# Out:
#                                           frequency  percentage  \
# 46_willingness_reorder_suppliers_variety
# Totalmente en desacuerdo                         73    0.426901
# Algo de acuerdo                                  42    0.245614
# Totalmente de acuerdo                            27    0.157895
# Algo en desacuerdo                               19    0.111111
# Ni de acuerdo ni en desacuerdo                   10    0.058480
#
#                                           cumulative_perc
# 46_willingness_reorder_suppliers_variety
# Totalmente en desacuerdo                         0.426901
# Algo de acuerdo                                  0.672515
# Totalmente de acuerdo                            0.830409
# Algo en desacuerdo                               0.941520
# Ni de acuerdo ni en desacuerdo                   1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index4.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('46_willingness_reorder_suppliers_variety')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(Filtro1['45_willingness_reorder_suppliers'])
table5
# Out:
#   45_willingness_reorder_suppliers  frequency  percentage  cumulative_perc
# 0         Totalmente en desacuerdo         97    0.567251         0.567251
# 1               Algo en desacuerdo         29    0.169591         0.736842
# 2            Totalmente de acuerdo         21    0.122807         0.859649
# 3                  Algo de acuerdo         16    0.093567         0.953216
# 4   Ni de acuerdo ni en desacuerdo          8    0.046784         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro5= table5[table5['frequency']>1]
Filtro5
# Out:
#   45_willingness_reorder_suppliers  frequency  percentage  cumulative_perc
# 0         Totalmente en desacuerdo         97    0.567251         0.567251
# 1               Algo en desacuerdo         29    0.169591         0.736842
# 2            Totalmente de acuerdo         21    0.122807         0.859649
# 3                  Algo de acuerdo         16    0.093567         0.953216
# 4   Ni de acuerdo ni en desacuerdo          8    0.046784         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index5= Filtro5.set_index('45_willingness_reorder_suppliers')
Filtro_index5
# Out:
#                                   frequency  percentage  cumulative_perc
# 45_willingness_reorder_suppliers
# Totalmente en desacuerdo                 97    0.567251         0.567251
# Algo en desacuerdo                       29    0.169591         0.736842
# Totalmente de acuerdo                    21    0.122807         0.859649
# Algo de acuerdo                          16    0.093567         0.953216
# Ni de acuerdo ni en desacuerdo            8    0.046784         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index5.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='45_willingness_reorder_suppliers'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table6= freq_tbl(Filtro1['44_willingness_inventory_management_suppliers'])
table6
# Out:
#   44_willingness_inventory_management_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo        120    0.701754
# 1                            Algo en desacuerdo         23    0.134503
# 2                Ni de acuerdo ni en desacuerdo         14    0.081871
# 3                         Totalmente de acuerdo          9    0.052632
# 4                               Algo de acuerdo          5    0.029240
#
#    cumulative_perc
# 0         0.701754
# 1         0.836257
# 2         0.918129
# 3         0.970760
# 4         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro6= table6[table6['frequency']>1]
Filtro6
# Out:
#   44_willingness_inventory_management_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo        120    0.701754
# 1                            Algo en desacuerdo         23    0.134503
# 2                Ni de acuerdo ni en desacuerdo         14    0.081871
# 3                         Totalmente de acuerdo          9    0.052632
# 4                               Algo de acuerdo          5    0.029240
#
#    cumulative_perc
# 0         0.701754
# 1         0.836257
# 2         0.918129
# 3         0.970760
# 4         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index6= Filtro6.set_index('44_willingness_inventory_management_suppliers')
Filtro_index6
# Out:
#                                                frequency  percentage  \
# 44_willingness_inventory_management_suppliers
# Totalmente en desacuerdo                             120    0.701754
# Algo en desacuerdo                                    23    0.134503
# Ni de acuerdo ni en desacuerdo                        14    0.081871
# Totalmente de acuerdo                                  9    0.052632
# Algo de acuerdo                                        5    0.029240
#
#                                                cumulative_perc
# 44_willingness_inventory_management_suppliers
# Totalmente en desacuerdo                              0.701754
# Algo en desacuerdo                                    0.836257
# Ni de acuerdo ni en desacuerdo                        0.918129
# Totalmente de acuerdo                                 0.970760
# Algo de acuerdo                                       1.000000

# %%
Filtro_index6["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Filtro1['42_willingness_share_inventory_data_suppliers'])
table7
# Out:
#   42_willingness_share_inventory_data_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo         97    0.567251
# 1                               Algo de acuerdo         38    0.222222
# 2                            Algo en desacuerdo         17    0.099415
# 3                         Totalmente de acuerdo         11    0.064327
# 4                Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.567251
# 1         0.789474
# 2         0.888889
# 3         0.953216
# 4         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>1]
Filtro7
# Out:
#   42_willingness_share_inventory_data_suppliers  frequency  percentage  \
# 0                      Totalmente en desacuerdo         97    0.567251
# 1                               Algo de acuerdo         38    0.222222
# 2                            Algo en desacuerdo         17    0.099415
# 3                         Totalmente de acuerdo         11    0.064327
# 4                Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.567251
# 1         0.789474
# 2         0.888889
# 3         0.953216
# 4         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index7= Filtro7.set_index('42_willingness_share_inventory_data_suppliers')
Filtro_index7
# Out:
#                                                frequency  percentage  \
# 42_willingness_share_inventory_data_suppliers
# Totalmente en desacuerdo                              97    0.567251
# Algo de acuerdo                                       38    0.222222
# Algo en desacuerdo                                    17    0.099415
# Totalmente de acuerdo                                 11    0.064327
# Ni de acuerdo ni en desacuerdo                         8    0.046784
#
#                                                cumulative_perc
# 42_willingness_share_inventory_data_suppliers
# Totalmente en desacuerdo                              0.567251
# Algo de acuerdo                                       0.789474
# Algo en desacuerdo                                    0.888889
# Totalmente de acuerdo                                 0.953216
# Ni de acuerdo ni en desacuerdo                        1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index7.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('42_willingness_share_inventory_data_suppliers')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8= freq_tbl(Filtro1['314_reception_delivery_packages'])
table8
# Out:
#   314_reception_delivery_packages  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo        118    0.690058         0.690058
# 1                 Algo de acuerdo         23    0.134503         0.824561
# 2           Totalmente de acuerdo         17    0.099415         0.923977
# 3              Algo en desacuerdo          9    0.052632         0.976608
# 4  Ni de acuerdo ni en desacuerdo          4    0.023392         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro8= table8[table8['frequency']>1]
Filtro8
# Out:
#   314_reception_delivery_packages  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo        118    0.690058         0.690058
# 1                 Algo de acuerdo         23    0.134503         0.824561
# 2           Totalmente de acuerdo         17    0.099415         0.923977
# 3              Algo en desacuerdo          9    0.052632         0.976608
# 4  Ni de acuerdo ni en desacuerdo          4    0.023392         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index8= Filtro8.set_index('314_reception_delivery_packages')
Filtro_index8
# Out:
#                                  frequency  percentage  cumulative_perc
# 314_reception_delivery_packages
# Totalmente en desacuerdo               118    0.690058         0.690058
# Algo de acuerdo                         23    0.134503         0.824561
# Totalmente de acuerdo                   17    0.099415         0.923977
# Algo en desacuerdo                       9    0.052632         0.976608
# Ni de acuerdo ni en desacuerdo           4    0.023392         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index8.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='314_reception_delivery_packages'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table9= freq_tbl(Filtro1['313_home_deliveries'])
table9
# Out:
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         65    0.380117         0.380117
# 1              Algo en desacuerdo         39    0.228070         0.608187
# 2           Totalmente de acuerdo         36    0.210526         0.818713
# 3                 Algo de acuerdo         21    0.122807         0.941520
# 4  Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro9= table9[table9['frequency']>1]
Filtro9
# Out:
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         65    0.380117         0.380117
# 1              Algo en desacuerdo         39    0.228070         0.608187
# 2           Totalmente de acuerdo         36    0.210526         0.818713
# 3                 Algo de acuerdo         21    0.122807         0.941520
# 4  Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index9= Filtro9.set_index('313_home_deliveries')
Filtro_index9
# Out:
#                                 frequency  percentage  cumulative_perc
# 313_home_deliveries
# Totalmente en desacuerdo               65    0.380117         0.380117
# Algo en desacuerdo                     39    0.228070         0.608187
# Totalmente de acuerdo                  36    0.210526         0.818713
# Algo de acuerdo                        21    0.122807         0.941520
# Ni de acuerdo ni en desacuerdo         10    0.058480         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index9["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table10= freq_tbl(Filtro1['312_payment_of_utilities'])
table10
# Out:
#          312_payment_of_utilities  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo        111    0.649123         0.649123
# 1           Totalmente de acuerdo         31    0.181287         0.830409
# 2  Ni de acuerdo ni en desacuerdo         10    0.058480         0.888889
# 3              Algo en desacuerdo         10    0.058480         0.947368
# 4                 Algo de acuerdo          9    0.052632         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro10= table10[table10['frequency']>1]
Filtro10
# Out:
#          312_payment_of_utilities  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo        111    0.649123         0.649123
# 1           Totalmente de acuerdo         31    0.181287         0.830409
# 2  Ni de acuerdo ni en desacuerdo         10    0.058480         0.888889
# 3              Algo en desacuerdo         10    0.058480         0.947368
# 4                 Algo de acuerdo          9    0.052632         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index10= Filtro10.set_index('312_payment_of_utilities')
Filtro_index10
# Out:
#                                 frequency  percentage  cumulative_perc
# 312_payment_of_utilities
# Totalmente en desacuerdo              111    0.649123         0.649123
# Totalmente de acuerdo                  31    0.181287         0.830409
# Ni de acuerdo ni en desacuerdo         10    0.058480         0.888889
# Algo en desacuerdo                     10    0.058480         0.947368
# Algo de acuerdo                         9    0.052632         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index10.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('312_payment_of_utilities')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table11= freq_tbl(Filtro1['311_topups'])
table11
# Out:
#                        311_topups  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         87    0.508772         0.508772
# 1           Totalmente de acuerdo         45    0.263158         0.771930
# 2              Algo en desacuerdo         22    0.128655         0.900585
# 3  Ni de acuerdo ni en desacuerdo         10    0.058480         0.959064
# 4                 Algo de acuerdo          7    0.040936         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro11= table11[table11['frequency']>1]
Filtro11
# Out:
#                        311_topups  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         87    0.508772         0.508772
# 1           Totalmente de acuerdo         45    0.263158         0.771930
# 2              Algo en desacuerdo         22    0.128655         0.900585
# 3  Ni de acuerdo ni en desacuerdo         10    0.058480         0.959064
# 4                 Algo de acuerdo          7    0.040936         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index11= Filtro11.set_index('311_topups')
Filtro_index11
# Out:
#                                 frequency  percentage  cumulative_perc
# 311_topups
# Totalmente en desacuerdo               87    0.508772         0.508772
# Totalmente de acuerdo                  45    0.263158         0.771930
# Algo en desacuerdo                     22    0.128655         0.900585
# Ni de acuerdo ni en desacuerdo         10    0.058480         0.959064
# Algo de acuerdo                         7    0.040936         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index11.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='311_topups'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table12= freq_tbl(Filtro1['69_why_not_services'])
table12
# Out:
#                                   69_why_not_services  frequency  percentage  \
# 0                            No conozco los servicios         48    0.280702
# 1                                         Es muy caro         24    0.140351
# 2             No creo que represente grandes ingresos         17    0.099415
# 3            No quiero involucrarme con la tecnología         16    0.093567
# 4                                       Se vende ropa         15    0.087719
# 5   Es muy caro,No conozco los servicios,No creo q...         10    0.058480
# 6   Es muy caro,No quiero involucrarme con la tecn...         10    0.058480
# 7   Es muy caro,No creo que represente grandes ing...          7    0.040936
# 8                                    no es requerido           4    0.023392
# 9   No conozco los servicios,No quiero involucrarm...          4    0.023392
# 10                                 no estamos listos           3    0.017544
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro12= table12[table12['frequency']>1]
Filtro12
# Out:
#                                   69_why_not_services  frequency  percentage  \
# 0                            No conozco los servicios         48    0.280702
# 1                                         Es muy caro         24    0.140351
# 2             No creo que represente grandes ingresos         17    0.099415
# 3            No quiero involucrarme con la tecnología         16    0.093567
# 4                                       Se vende ropa         15    0.087719
# 5   Es muy caro,No conozco los servicios,No creo q...         10    0.058480
# 6   Es muy caro,No quiero involucrarme con la tecn...         10    0.058480
# 7   Es muy caro,No creo que represente grandes ing...          7    0.040936
# 8                                    no es requerido           4    0.023392
# 9   No conozco los servicios,No quiero involucrarm...          4    0.023392
# 10                                 no estamos listos           3    0.017544
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index12= Filtro12.set_index('69_why_not_services')
Filtro_index12
# Out:
#                                                     frequency  percentage  \
# 69_why_not_services
# No conozco los servicios                                   48    0.280702
# Es muy caro                                                24    0.140351
# No creo que represente grandes ingresos                    17    0.099415
# No quiero involucrarme con la tecnología                   16    0.093567
# Se vende ropa                                              15    0.087719
# Es muy caro,No conozco los servicios,No creo qu...         10    0.058480
# Es muy caro,No quiero involucrarme con la tecno...         10    0.058480
# Es muy caro,No creo que represente grandes ingr...          7    0.040936
# no es requerido                                             4    0.023392
# No conozco los servicios,No quiero involucrarme...          4    0.023392
# no estamos listos                                           3    0.017544
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index12["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table13= freq_tbl(Micro_Retailer['60_services'])
table13
# Out:
#                                           60_services  frequency  percentage  \
# 0                                             Ninguno         44    0.257310
# 1                                 Entrega a domicilio         15    0.087719
# 2                                  Recarga telefónica          7    0.040936
# 3   Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 4              Entrega a domicilio,Recarga telefónica          2    0.011696
# 5                                Toma de papa nicolau          1    0.005848
# 6                                      Renta de local          1    0.005848
# 7                                               venta          1    0.005848
# 8   Entrega a domicilio,Recarga telefónica,Recepci...          1    0.005848
# 9   Entrega a domicilio,Pago de servicios públicos...          1    0.005848
# 10  Pago de servicios públicos (e.g. Yastas),Recar...          1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro13= table13[table13['frequency']>1]
Filtro13
# Out:
#                                          60_services  frequency  percentage  \
# 0                                            Ninguno         44    0.257310
# 1                                Entrega a domicilio         15    0.087719
# 2                                 Recarga telefónica          7    0.040936
# 3  Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 4             Entrega a domicilio,Recarga telefónica          2    0.011696
#
#    cumulative_perc
# 0         0.571429
# 1         0.766234
# 2         0.857143
# 3         0.883117
# 4         0.909091

# %%
#Ajusto el indice de mi dataframe
Filtro_index13= Filtro13.set_index('60_services')
Filtro_index13
# Out:
#                                                     frequency  percentage  \
# 60_services
# Ninguno                                                    44    0.257310
# Entrega a domicilio                                        15    0.087719
# Recarga telefónica                                          7    0.040936
# Entrega a domicilio,Pago de servicios públicos ...          2    0.011696
# Entrega a domicilio,Recarga telefónica                      2    0.011696
#
#                                                     cumulative_perc
# 60_services
# Ninguno                                                    0.571429
# Entrega a domicilio                                        0.766234
# Recarga telefónica                                         0.857143
# Entrega a domicilio,Pago de servicios públicos ...         0.883117
# Entrega a domicilio,Recarga telefónica                     0.909091

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index13.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('60_services')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table14= freq_tbl(Filtro1['_title'])
table14
# Out:
#               _title  frequency  percentage  cumulative_perc
# 0   November 9, 2022         73    0.426901         0.426901
# 1  November 10, 2022         26    0.152047         0.578947
# 2   November 7, 2022         20    0.116959         0.695906
# 3   November 3, 2022         16    0.093567         0.789474
# 4  November 12, 2022         15    0.087719         0.877193
# 5   November 8, 2022         10    0.058480         0.935673
# 6   November 4, 2022          9    0.052632         0.988304
# 7  November 11, 2022          1    0.005848         0.994152
# 8   November 2, 2022          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro14= table14[table14['frequency']>1]
Filtro14
# Out:
#               _title  frequency  percentage  cumulative_perc
# 0   November 9, 2022         73    0.426901         0.426901
# 1  November 10, 2022         26    0.152047         0.578947
# 2   November 7, 2022         20    0.116959         0.695906
# 3   November 3, 2022         16    0.093567         0.789474
# 4  November 12, 2022         15    0.087719         0.877193
# 5   November 8, 2022         10    0.058480         0.935673
# 6   November 4, 2022          9    0.052632         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index14= Filtro14.set_index('_title')
Filtro_index14
# Out:
#                    frequency  percentage  cumulative_perc
# _title
# November 9, 2022          73    0.426901         0.426901
# November 10, 2022         26    0.152047         0.578947
# November 7, 2022          20    0.116959         0.695906
# November 3, 2022          16    0.093567         0.789474
# November 12, 2022         15    0.087719         0.877193
# November 8, 2022          10    0.058480         0.935673
# November 4, 2022           9    0.052632         0.988304

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index14.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='_title'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table15= freq_tbl(Filtro1['193_sales_planning_tools'])
table15
# Out:
#                    193_sales_planning_tools  frequency  percentage  \
# 0                                   Ninguna         71    0.415205
# 1                                  Cuaderno         46    0.269006
# 2                                     Excel         17    0.099415
# 3                          Aplicación móvil         10    0.058480
# 4                    Software especializado         10    0.058480
# 5                            Cuaderno,Excel          3    0.017544
# 6              Excel,Software especializado          3    0.017544
# 7                          Cuaderno,Ninguna          2    0.011696
# 8                                    Mental          1    0.005848
# 9                      Por temporada de pan          1    0.005848
# 10                           Sobre demanda           1    0.005848
# 11                                    Other          1    0.005848
# 12                                Catálogo           1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro15= table15[table15['frequency']>1]
Filtro15
# Out:
#        193_sales_planning_tools  frequency  percentage  cumulative_perc
# 0                       Ninguna         71    0.415205         0.415205
# 1                      Cuaderno         46    0.269006         0.684211
# 2                         Excel         17    0.099415         0.783626
# 3              Aplicación móvil         10    0.058480         0.842105
# 4        Software especializado         10    0.058480         0.900585
# 5                Cuaderno,Excel          3    0.017544         0.918129
# 6  Excel,Software especializado          3    0.017544         0.935673
# 7              Cuaderno,Ninguna          2    0.011696         0.947368

# %%
#Ajusto el indice de mi dataframe
Filtro_index15= Filtro15.set_index('193_sales_planning_tools')
Filtro_index15
# Out:
#                               frequency  percentage  cumulative_perc
# 193_sales_planning_tools
# Ninguna                              71    0.415205         0.415205
# Cuaderno                             46    0.269006         0.684211
# Excel                                17    0.099415         0.783626
# Aplicación móvil                     10    0.058480         0.842105
# Software especializado               10    0.058480         0.900585
# Cuaderno,Excel                        3    0.017544         0.918129
# Excel,Software especializado          3    0.017544         0.935673
# Cuaderno,Ninguna                      2    0.011696         0.947368

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index15["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table16= freq_tbl(Filtro1['214_customer_relationship_tools'])
table16
# Out:
#     214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                    Redes sociales         45    0.263158         0.263158
# 1                           Ninguna         39    0.228070         0.491228
# 2                  Aplicación móvil         36    0.210526         0.701754
# 3   Aplicación móvil,Redes sociales         15    0.087719         0.789474
# 4                        Publicidad         14    0.081871         0.871345
# 5                          Cuaderno         13    0.076023         0.947368
# 6                          Teléfono          2    0.011696         0.959064
# 7                           Físico           2    0.011696         0.970760
# 8           Cuaderno,Redes sociales          1    0.005848         0.976608
# 9        Aplicación móvil,De frente          1    0.005848         0.982456
# 10         Aplicación móvil,Ninguna          1    0.005848         0.988304
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro16= table16[table16['frequency']>1]
Filtro16
# Out:
#    214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                   Redes sociales         45    0.263158         0.263158
# 1                          Ninguna         39    0.228070         0.491228
# 2                 Aplicación móvil         36    0.210526         0.701754
# 3  Aplicación móvil,Redes sociales         15    0.087719         0.789474
# 4                       Publicidad         14    0.081871         0.871345
# 5                         Cuaderno         13    0.076023         0.947368
# 6                         Teléfono          2    0.011696         0.959064
# 7                          Físico           2    0.011696         0.970760

# %%
#Ajusto el indice de mi dataframe
Filtro_index16= Filtro16.set_index('214_customer_relationship_tools')
Filtro_index16
# Out:
#                                  frequency  percentage  cumulative_perc
# 214_customer_relationship_tools
# Redes sociales                          45    0.263158         0.263158
# Ninguna                                 39    0.228070         0.491228
# Aplicación móvil                        36    0.210526         0.701754
# Aplicación móvil,Redes sociales         15    0.087719         0.789474
# Publicidad                              14    0.081871         0.871345
# Cuaderno                                13    0.076023         0.947368
# Teléfono                                 2    0.011696         0.959064
# Físico                                   2    0.011696         0.970760

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index16.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('214_customer_relationship_tools')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table17= freq_tbl(Filtro1['189_payment_methods'])
table17
# Out:
#                                  189_payment_methods  frequency  percentage  \
# 0                                           Efectivo         69    0.403509
# 1             Efectivo,Tarjeta de débito y/o crédito         37    0.216374
# 2  Efectivo,Tarjeta de débito y/o crédito,Transfe...         35    0.204678
# 3               Efectivo,Transferencia interbancaria         26    0.152047
# 4  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          2    0.011696
# 5  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          1    0.005848
# 6                      Tarjeta de débito y/o crédito          1    0.005848
#
#    cumulative_perc
# 0         0.403509
# 1         0.619883
# 2         0.824561
# 3         0.976608
# 4         0.988304
# 5         0.994152
# 6         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro17= table17[table17['frequency']>1]
Filtro17
# Out:
#                                  189_payment_methods  frequency  percentage  \
# 0                                           Efectivo         69    0.403509
# 1             Efectivo,Tarjeta de débito y/o crédito         37    0.216374
# 2  Efectivo,Tarjeta de débito y/o crédito,Transfe...         35    0.204678
# 3               Efectivo,Transferencia interbancaria         26    0.152047
# 4  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          2    0.011696
#
#    cumulative_perc
# 0         0.403509
# 1         0.619883
# 2         0.824561
# 3         0.976608
# 4         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index17= Filtro17.set_index('189_payment_methods')
Filtro_index17
# Out:
#                                                     frequency  percentage  \
# 189_payment_methods
# Efectivo                                                   69    0.403509
# Efectivo,Tarjeta de débito y/o crédito                     37    0.216374
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         35    0.204678
# Efectivo,Transferencia interbancaria                       26    0.152047
# Aplicación móvil (e.g. CODI),Efectivo,Tarjeta d...          2    0.011696
#
#                                                     cumulative_perc
# 189_payment_methods
# Efectivo                                                   0.403509
# Efectivo,Tarjeta de débito y/o crédito                     0.619883
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         0.824561
# Efectivo,Transferencia interbancaria                       0.976608
# Aplicación móvil (e.g. CODI),Efectivo,Tarjeta d...         0.988304

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index17.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='189_payment_methods'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table18= freq_tbl(Filtro1['210_sales_channels'])
table18
# Out:
#                                    210_sales_channels  frequency  percentage  \
# 0                                            WhatsApp         26    0.152047
# 1                             Llamada a Teléfono fijo         19    0.111111
# 2   Redes sociales (e.g. Facebook, Instagram),What...         17    0.099415
# 3           Redes sociales (e.g. Facebook, Instagram)         16    0.093567
# 4                          Llamada a Teléfono celular         14    0.081871
# 5   Llamada a Teléfono celular,Redes sociales (e.g...         14    0.081871
# 6                 Llamada a Teléfono celular,WhatsApp          8    0.046784
# 7                         conocidos paquetes cerrados          7    0.040936
# 8                                   Página web propia          6    0.035088
# 9   Llamada a Teléfono fijo,Redes sociales (e.g. F...          5    0.029240
# 10  Aplicación móvil (e.g. Rappi, Uber Eats),Llama...          3    0.017544
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro18= table18[table18['frequency']>1]
Filtro18
# Out:
#                                    210_sales_channels  frequency  percentage  \
# 0                                            WhatsApp         26    0.152047
# 1                             Llamada a Teléfono fijo         19    0.111111
# 2   Redes sociales (e.g. Facebook, Instagram),What...         17    0.099415
# 3           Redes sociales (e.g. Facebook, Instagram)         16    0.093567
# 4                          Llamada a Teléfono celular         14    0.081871
# 5   Llamada a Teléfono celular,Redes sociales (e.g...         14    0.081871
# 6                 Llamada a Teléfono celular,WhatsApp          8    0.046784
# 7                         conocidos paquetes cerrados          7    0.040936
# 8                                   Página web propia          6    0.035088
# 9   Llamada a Teléfono fijo,Redes sociales (e.g. F...          5    0.029240
# 10  Aplicación móvil (e.g. Rappi, Uber Eats),Llama...          3    0.017544
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index18= Filtro18.set_index('210_sales_channels')
Filtro_index18
# Out:
#                                                     frequency  percentage  \
# 210_sales_channels
# WhatsApp                                                   26    0.152047
# Llamada a Teléfono fijo                                    19    0.111111
# Redes sociales (e.g. Facebook, Instagram),WhatsApp         17    0.099415
# Redes sociales (e.g. Facebook, Instagram)                  16    0.093567
# Llamada a Teléfono celular                                 14    0.081871
# Llamada a Teléfono celular,Redes sociales (e.g....         14    0.081871
# Llamada a Teléfono celular,WhatsApp                         8    0.046784
# conocidos paquetes cerrados                                 7    0.040936
# Página web propia                                           6    0.035088
# Llamada a Teléfono fijo,Redes sociales (e.g. Fa...          5    0.029240
# Aplicación móvil (e.g. Rappi, Uber Eats),Llamad...          3    0.017544
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index18["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table19= freq_tbl(Filtro1['18_sales_records'])
table19
# Out:
#                                      18_sales_records  frequency  percentage  \
# 0                                            En papel         79    0.461988
# 1                Software especializado + computadora         25    0.146199
# 2                                          No lo hago         20    0.116959
# 3                                            En Excel         20    0.116959
# 4                         Caja registradora (análoga)          6    0.035088
# 5                                   En Excel,En papel          6    0.035088
# 6                                           Contadora          5    0.029240
# 7   Aplicación móvil (i.e. App) + smartphone,Softw...          3    0.017544
# 8            Aplicación móvil (i.e. App) + smartphone          1    0.005848
# 9   Aplicación móvil (i.e. App) + smartphone,Caja ...          1    0.005848
# 10                                             Notas           1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro19= table19[table19['frequency']>1]
Filtro19
# Out:
#                                     18_sales_records  frequency  percentage  \
# 0                                           En papel         79    0.461988
# 1               Software especializado + computadora         25    0.146199
# 2                                         No lo hago         20    0.116959
# 3                                           En Excel         20    0.116959
# 4                        Caja registradora (análoga)          6    0.035088
# 5                                  En Excel,En papel          6    0.035088
# 6                                          Contadora          5    0.029240
# 7  Aplicación móvil (i.e. App) + smartphone,Softw...          3    0.017544
#
#    cumulative_perc
# 0         0.461988
# 1         0.608187
# 2         0.725146
# 3         0.842105
# 4         0.877193
# 5         0.912281
# 6         0.941520
# 7         0.959064

# %%
#Ajusto el indice de mi dataframe
Filtro_index19= Filtro19.set_index('18_sales_records')
Filtro_index19
# Out:
#                                                     frequency  percentage  \
# 18_sales_records
# En papel                                                   79    0.461988
# Software especializado + computadora                       25    0.146199
# No lo hago                                                 20    0.116959
# En Excel                                                   20    0.116959
# Caja registradora (análoga)                                 6    0.035088
# En Excel,En papel                                           6    0.035088
# Contadora                                                   5    0.029240
# Aplicación móvil (i.e. App) + smartphone,Softwa...          3    0.017544
#
#                                                     cumulative_perc
# 18_sales_records
# En papel                                                   0.461988
# Software especializado + computadora                       0.608187
# ...

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index19.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('18_sales_records')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table20= freq_tbl(Filtro1['5_change_store_space_last_year'])
table20
# Out:
#   5_change_store_space_last_year  frequency  percentage  cumulative_perc
# 0                      No cambió        132    0.771930         0.771930
# 1                    Aumentó 25%         13    0.076023         0.847953
# 2                  Disminuyó 15%         11    0.064327         0.912281
# 3                    Aumentó 15%          4    0.023392         0.935673
# 4              Aumentó 50% o más          4    0.023392         0.959064
# 5                  Disminuyó 25%          4    0.023392         0.982456
# 6            Disminuyó 50% o más          3    0.017544         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro20= table20[table20['frequency']>1]
Filtro20
# Out:
#   5_change_store_space_last_year  frequency  percentage  cumulative_perc
# 0                      No cambió        132    0.771930         0.771930
# 1                    Aumentó 25%         13    0.076023         0.847953
# 2                  Disminuyó 15%         11    0.064327         0.912281
# 3                    Aumentó 15%          4    0.023392         0.935673
# 4              Aumentó 50% o más          4    0.023392         0.959064
# 5                  Disminuyó 25%          4    0.023392         0.982456
# 6            Disminuyó 50% o más          3    0.017544         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index20= Filtro20.set_index('5_change_store_space_last_year')
Filtro_index20
# Out:
#                                 frequency  percentage  cumulative_perc
# 5_change_store_space_last_year
# No cambió                             132    0.771930         0.771930
# Aumentó 25%                            13    0.076023         0.847953
# Disminuyó 15%                          11    0.064327         0.912281
# Aumentó 15%                             4    0.023392         0.935673
# Aumentó 50% o más                       4    0.023392         0.959064
# Disminuyó 25%                           4    0.023392         0.982456
# Disminuyó 50% o más                     3    0.017544         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index20["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
